# %% [markdown]
# In this project we are going to analyze the dateset of heart disease patients

# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('heart_disease_dataset.csv')
data
# Out:
#      Age  Gender  Cholesterol  Blood Pressure  Heart Rate  Smoking  \
# 0     75  Female          228             119          66  Current
# 1     48    Male          204             165          62  Current
# 2     53    Male          234              91          67    Never
# 3     69  Female          192              90          72  Current
# 4     62  Female          172             163          93    Never
# ..   ...     ...          ...             ...         ...      ...
# 995   56  Female          269             111          86    Never
# 996   78  Female          334             145          76    Never
# 997   79    Male          151             179          81    Never
# 998   60  Female          326             151          68   Former
# 999   53    Male          226             116          82  Current
#
#     Alcohol Intake  Exercise Hours Family History Diabetes Obesity  \
# 0            Heavy               1             No       No     Yes
# 1              NaN               5             No       No      No
# 2            Heavy               3            Yes       No     Yes
# 3              NaN               4             No      Yes      No
# 4              NaN               6             No      Yes      No
# ..             ...             ...            ...      ...     ...
# 995          Heavy               5             No      Yes     Yes
# 996            NaN               6             No       No      No
# 997       Moderate               4            Yes       No     Yes
# 998            NaN               8            Yes      Yes      No
# 999            NaN               6             No       No     Yes
#
#      Stress Level  Blood Sugar Exercise Induced Angina   Chest Pain Type  \
# 0               8          119                     Yes   Atypical Angina
# 1               9           70                     Yes    Typical Angina
# 2               5          196                     Yes   Atypical Angina
# 3               7          107                     Yes  Non-anginal Pain
# 4               2          183                     Yes      Asymptomatic
# ..            ...          ...                     ...               ...
# 995            10          120                      No  Non-anginal Pain
# 996            10          196                     Yes    Typical Angina
# 997             8          189                     Yes      Asymptomatic
# 998             5          174                     Yes   Atypical Angina
# 999             5          161                     Yes      Asymptomatic
#
#      Heart Disease
# 0                1
# 1                0
# 2                1
# 3                0
# 4                0
# ..             ...
# 995              1
# 996              1
# 997              0
# 998              1
# 999              1
#
# [1000 rows x 16 columns]

# %%
data.head(10)
# Out:
#    Age  Gender  Cholesterol  Blood Pressure  Heart Rate  Smoking  \
# 0   75  Female          228             119          66  Current
# 1   48    Male          204             165          62  Current
# 2   53    Male          234              91          67    Never
# 3   69  Female          192              90          72  Current
# 4   62  Female          172             163          93    Never
# 5   77    Male          309             110          73    Never
# 6   64  Female          211             105          86   Former
# 7   60  Female          208             148          83    Never
# 8   37  Female          317             137          66  Current
# 9   63    Male          204             141          68   Former
#
#   Alcohol Intake  Exercise Hours Family History Diabetes Obesity  \
# 0          Heavy               1             No       No     Yes
# 1            NaN               5             No       No      No
# 2          Heavy               3            Yes       No     Yes
# 3            NaN               4             No      Yes      No
# 4            NaN               6             No      Yes      No
# 5            NaN               0             No      Yes     Yes
# 6          Heavy               8            Yes      Yes     Yes
# 7       Moderate               4             No      Yes     Yes
# 8          Heavy               3             No      Yes     Yes
# 9          Heavy               8             No      Yes      No
#
#    Stress Level  Blood Sugar Exercise Induced Angina   Chest Pain Type  \
# 0             8          119                     Yes   Atypical Angina
# 1             9           70                     Yes    Typical Angina
# 2             5          196                     Yes   Atypical Angina
# 3             7          107                     Yes  Non-anginal Pain
# 4             2          183                     Yes      Asymptomatic
# 5             4          122                     Yes      Asymptomatic
# 6             2          120                      No    Typical Angina
# 7             2          113                     Yes      Asymptomatic
# 8             5          114                      No  Non-anginal Pain
# 9             3          107                      No      Asymptomatic
#
#    Heart Disease
# 0              1
# 1              0
# 2              1
# 3              0
# 4              0
# 5              1
# 6              1
# 7              1
# 8              0
# 9              1

# %%
data.tail(10)
# Out:
#      Age  Gender  Cholesterol  Blood Pressure  Heart Rate  Smoking  \
# 990   54    Male          304             112          86   Former
# 991   26  Female          215             100          74    Never
# 992   28  Female          220             102          73  Current
# 993   70  Female          346             110          62    Never
# 994   52    Male          248             159          76   Former
# 995   56  Female          269             111          86    Never
# 996   78  Female          334             145          76    Never
# 997   79    Male          151             179          81    Never
# 998   60  Female          326             151          68   Former
# 999   53    Male          226             116          82  Current
#
#     Alcohol Intake  Exercise Hours Family History Diabetes Obesity  \
# 990            NaN               8            Yes       No     Yes
# 991          Heavy               7             No      Yes      No
# 992       Moderate               7            Yes      Yes     Yes
# 993            NaN               1            Yes      Yes      No
# 994       Moderate               9             No      Yes     Yes
# 995          Heavy               5             No      Yes     Yes
# 996            NaN               6             No       No      No
# 997       Moderate               4            Yes       No     Yes
# 998            NaN               8            Yes      Yes      No
# 999            NaN               6             No       No     Yes
#
#      Stress Level  Blood Sugar Exercise Induced Angina   Chest Pain Type  \
# 990             6          111                      No      Asymptomatic
# 991            10          135                      No   Atypical Angina
# 992            10          102                      No    Typical Angina
# 993             8          130                     Yes      Asymptomatic
# 994             2          152                     Yes      Asymptomatic
# 995            10          120                      No  Non-anginal Pain
# 996            10          196                     Yes    Typical Angina
# 997             8          189                     Yes      Asymptomatic
# 998             5          174                     Yes   Atypical Angina
# 999             5          161                     Yes      Asymptomatic
#
#      Heart Disease
# 990              1
# 991              0
# 992              0
# 993              1
# 994              1
# 995              1
# 996              1
# 997              0
# 998              1
# 999              1

# %%
data.sample(5)
# Out:
#      Age  Gender  Cholesterol  Blood Pressure  Heart Rate  Smoking  \
# 763   50  Female          317             148          71  Current
# 51    54  Female          348             129          97  Current
# 109   37  Female          226             173          86  Current
# 303   75  Female          246             142          66    Never
# 164   52    Male          339             169          88    Never
#
#     Alcohol Intake  Exercise Hours Family History Diabetes Obesity  \
# 763       Moderate               1             No       No     Yes
# 51           Heavy               4            Yes       No      No
# 109       Moderate               7             No      Yes      No
# 303       Moderate               9            Yes       No     Yes
# 164            NaN               8            Yes       No      No
#
#      Stress Level  Blood Sugar Exercise Induced Angina   Chest Pain Type  \
# 763             4          116                     Yes    Typical Angina
# 51              9          187                     Yes   Atypical Angina
# 109             2          139                      No      Asymptomatic
# 303             7          103                     Yes  Non-anginal Pain
# 164             3          157                      No   Atypical Angina
#
#      Heart Disease
# 763              0
# 51               1
# 109              0
# 303              1
# 164              1

# %% [markdown]
# 🔵 Section 1 — Data Understanding (Q1–Q8)
#
# 1. What is the shape of the dataset (rows and columns)?

# %%
data.shape
# Out:
# (1000, 16)

# %% [markdown]
# Dataset have 1000 rows and 16 columns

# %% [markdown]
# 2. What are the column names and their data types?

# %%
data.columns
# Out:
# Index(['Age', 'Gender', 'Cholesterol', 'Blood Pressure', 'Heart Rate',
#        'Smoking', 'Alcohol Intake', 'Exercise Hours', 'Family History',
#        'Diabetes', 'Obesity', 'Stress Level', 'Blood Sugar',
#        'Exercise Induced Angina', 'Chest Pain Type', 'Heart Disease'],
#       dtype='object')

# %% [markdown]
# these are all the columns of dataset

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1000 non-null   int64
#  1   Gender                   1000 non-null   object
#  2   Cholesterol              1000 non-null   int64
#  3   Blood Pressure           1000 non-null   int64
#  4   Heart Rate               1000 non-null   int64
#  5   Smoking                  1000 non-null   object
#  6   Alcohol Intake           660 non-null    object
#  7   Exercise Hours           1000 non-null   int64
#  8   Family History           1000 non-null   object
#  9   Diabetes                 1000 non-null   object
#  10  Obesity                  1000 non-null   object
#  11  Stress Level             1000 non-null   int64
#  12  Blood Sugar              1000 non-null   int64
#  13  Exercise Induced Angina  1000 non-null   object
#  14  Chest Pain Type          1000 non-null   object
#  15  Heart Disease            1000 non-null   int64
# dtypes: int64(8), object(8)
# memory usage: 125.1+ KB

# %% [markdown]
# data type of each column is mentioned above.

# %% [markdown]
# 3. How many numerical and categorical columns are there?

# %%
data.dtypes.value_counts()
# Out:
# int64     8
# object    8
# Name: count, dtype: int64

# %% [markdown]
# there are:
#     numerical columns = 8,
#     categorical cloumns = 8

# %% [markdown]
# 4. What are the basic statistics (mean, median, min, max) for all numerical columns?

# %%
data.describe()
# Out:
#                Age  Cholesterol  Blood Pressure   Heart Rate  Exercise Hours  \
# count  1000.000000  1000.000000       1000.0000  1000.000000     1000.000000
# mean     52.293000   249.939000        135.2810    79.204000        4.529000
# std      15.727126    57.914673         26.3883    11.486092        2.934241
# min      25.000000   150.000000         90.0000    60.000000        0.000000
# 25%      39.000000   200.000000        112.7500    70.000000        2.000000
# 50%      52.000000   248.000000        136.0000    79.000000        4.500000
# 75%      66.000000   299.000000        159.0000    89.000000        7.000000
# max      79.000000   349.000000        179.0000    99.000000        9.000000
#
#        Stress Level  Blood Sugar  Heart Disease
# count   1000.000000  1000.000000    1000.000000
# mean       5.646000   134.941000       0.392000
# std        2.831024    36.699624       0.488441
# min        1.000000    70.000000       0.000000
# 25%        3.000000   104.000000       0.000000
# 50%        6.000000   135.000000       0.000000
# 75%        8.000000   167.000000       1.000000
# max       10.000000   199.000000       1.000000

# %% [markdown]
# we can see mean, median,min and max for all numerical column

# %% [markdown]
# 5. Are there any missing values? If yes, in which columns and how many?

# %%
data.isnull().sum()
# Out:
# Age                          0
# Gender                       0
# Cholesterol                  0
# Blood Pressure               0
# Heart Rate                   0
# Smoking                      0
# Alcohol Intake             340
# Exercise Hours               0
# Family History               0
# Diabetes                     0
# Obesity                      0
# Stress Level                 0
# Blood Sugar                  0
# Exercise Induced Angina      0
# Chest Pain Type              0
# Heart Disease                0
# dtype: int64

# %% [markdown]
# yes, there are 340 missing value in Alcohol Intake column.

# %% [markdown]
# 6. Are there any duplicate rows?

# %%
data.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %% [markdown]
# No, there are no duplicated data.

# %% [markdown]
# 7. What is the class balance — how many patients have heart disease vs not?

# %%
data.sample(5)
# Out:
#      Age  Gender  Cholesterol  Blood Pressure  Heart Rate  Smoking  \
# 779   72  Female          280             139          62  Current
# 460   48  Female          279             164          74  Current
# 27    63    Male          273             103          64    Never
# 627   70  Female          188             154          86  Current
# 662   49    Male          212             140          75    Never
#
#     Alcohol Intake  Exercise Hours Family History Diabetes Obesity  \
# 779            NaN               0             No      Yes     Yes
# 460            NaN               7             No      Yes      No
# 27             NaN               6            Yes      Yes     Yes
# 627       Moderate               2             No       No     Yes
# 662          Heavy               9            Yes       No      No
#
#      Stress Level  Blood Sugar Exercise Induced Angina  Chest Pain Type  \
# 779            10          156                     Yes   Typical Angina
# 460             2          119                      No  Atypical Angina
# 27              9          104                      No   Typical Angina
# 627             4          109                      No     Asymptomatic
# 662             9          139                      No  Atypical Angina
#
#      Heart Disease
# 779              1
# 460              0
# 27               1
# 627              0
# 662              0

# %%
data['Heart Disease'].value_counts()
# Out:
# Heart Disease
# 0    608
# 1    392
# Name: count, dtype: int64

# %% [markdown]
# Heart disease patient = 392
#
# Non Heard disease patient = 608

# %% [markdown]
# 8. What is the age range of patients in the dataset?

# %%
youngest_age = data['Age'].min()
oldest_age = data['Age'].max()
age_range = oldest_age - youngest_age
print(f"Youngest Age = {youngest_age}")
print(f"Oldest Age = {oldest_age}")
print(f"Range of Age = {oldest_age - youngest_age}")
# Out:
# Youngest Age = 25
# Oldest Age = 79
# Range of Age = 54

# %% [markdown]
# 🟠 Section 2 — Data Cleaning (Q9–Q16)
#
# 9. Handle the missing values in the Alcohol Intake column — what strategy will you use and why?
